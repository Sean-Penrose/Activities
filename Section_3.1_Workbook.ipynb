# %% [markdown]
# # Section 3.1 Workbook

# %% [markdown]
# What kind of language is Python considered?
# - Python is an interpreted language.
# What is a natural language?
# - This is a type of language that forms on it's own by people and can be compared to slang or a dialect
# What are algorithms?
# - a set of instructions to to execute a task or solve a problem
# What is the program we use to write Python in?
# - We use VSCode.
# What is the file extension of a Python file?
# - .py
# What is the area called where we put in our commands?
# - The Terminal
# What is the #1 rule of coding / debugging?
# - Complexity is the enemy of efficiency
